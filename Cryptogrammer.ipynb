# %%
def cencrypt(text,s):
     result=''
     for i in range(len(text)):
          char=text[i] #iterates the index of the string
          if (char.isupper()):
               result+=chr((ord(char)+s-65)%26+65) #codes the string
          elif char==' ':
               result+=' '
          else:
               result+=chr((ord(char)+s-97)%26+97)
     print(text,'--->>>',result)
def cdecrypt():
     if (text.isupper()):
          letters='ABCDEFGHIJKLMNOPQRSTUVWXYZ'
          for i in range(len(letters)):
                    x=''
                    for a in text:
                         if a in letters:
                              num=letters.find(a)
                              num=num-i
                              if num<0:
                                   num=num+len(letters)
                              x=x+letters[num]
                         else:
                              x=x+a
                    print('Shift',i,':',x)
     if (text.islower()):
          letters='abcdefghijklmnopqrstuvwxyz'
          for i in range(len(letters)):
                    x=''
                    for a in text:
                         if a in letters:
                              num=letters.find(a)
                              num=num-i
                              if num<0:
                                   num=num+len(letters)
                              x=x+letters[num]
                         else:
                              x=x+a
                    print('Shift',i,':',x)
def atbash():
     result=''
     for i in range(len(text)):
          char=text[i]
          if (char.isupper()):
               result+=chr(155-ord(char))
          else:
               result+=chr(219-ord(char))
         
          space=result.count("»")
          S=1
          while S<=space:
               S=S+1
               result=result.replace("»"," ")
     print(text,'--->>>',result)
def ca1z26(text):
     result=''
     for i in range(len(text)):
          char=text[i] #iterates the index of the string
          if (char.isupper()):
               result+=str(ord(char)-64)+'-'
          elif char==' ':
               result+=' '
          else:
               result+=str(ord(char)-96)+'-'
     result=result[:len(result)-1]
     space=result.count(" ")
     s=1
     while s<=space:
          index=result.find(" ")
          result=result[:index-1]+"*"+result[index+1:]
          s=s+1
     result=result.replace("*"," ",space)
     print(text,'--->>>',result)
def da1z26(text):
     result = ""    
     x = text.split() # Split string at " "
     for y in x:
          newtext=y.split('-')     #Split string at "-"
          for value in newtext:
               char=chr(int(value)+64)        #Decodes each character
               result+=char       #Joins the characters in a word
          result+=' '            #Puts Space between words
     print(text,'--->>>',result)  
         
         
               
         
print('CRYPTOGRAMMER')
print('____________________________')
print('''
Atbash Cipher: This cipher reverses the letters of the alphabet.For example: a will be z, b will be y and so on.

Caesar Cipher:This is a cipher in which each letter is shifted a certain number of places down the alphabet.

A1Z26:This is a cipher in which each letter corresponds to a number.
''')
while (True):
    cipher=input("\n\nChoose a cipher(Atbash,Caesar,A1Z26):")
    print('''
    To code is to get the coded form of the given word/sentence.
    To decode is to get the original word/sentence from the coded word.
    ''')
    c_d=input("Do you want to code or decode?:")
    print()

    if cipher=='Caesar' or cipher=='CAESAR' or cipher=='caesar':
        text=input('Enter a sentence:')
        if c_d=='Code' or c_d=='code' or c_d=='CODE':
              s=int(input('Enter shift pattern:'))
              cencrypt(text,s)
        elif c_d=='Decode' or c_d=='decode' or c_d=='DECODE':
              cdecrypt()
    if cipher=='Atbash' or cipher=='atbash' or cipher=='ATBASH':
        text=input('Enter a sentence:')
        atbash()
        
    if cipher=='A1Z26':
        if c_d=='Code' or c_d=='code' or c_d=='CODE':
              text=input('Enter a sentence:')
              ca1z26(text)
        elif c_d=='Decode' or c_d=='decode' or c_d=='DECODE':
              text=input('Enter the code(separate each character in by a hyphen(-)):')
              da1z26(text)
    choice=input('Do you want to continue? (Y/N) ')
    if choice=='Y' or  choice=='y':
      continue;
    else:
      break;
    input()
# Out:
# CRYPTOGRAMMER
# ____________________________
#
# Atbash Cipher: This cipher reverses the letters of the alphabet.For example: a will be z, b will be y and so on.
#
# Caesar Cipher:This is a cipher in which each letter is shifted a certain number of places down the alphabet.
#
# A1Z26:This is a cipher in which each letter corresponds to a number.
#
#
#
# Choose a cipher(Atbash,Caesar,A1Z26):Atbash
#
#     To code is to get the coded form of the given word/sentence.
#     To decode is to get the original word/sentence from the coded word.
#
# Do you want to code or decode?:Code
#
# Enter a sentence:hii
# hii --->>> srr
# Do you want to continue? (Y/N) B
